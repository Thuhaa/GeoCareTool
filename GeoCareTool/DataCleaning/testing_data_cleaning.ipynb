# %%
from preprocessing import *
import pandas as pd

df = pd.read_csv("toy_datasets/combined_NN_tegucigalpa.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             245 non-null    object
#  1   place_id         245 non-null    object
#  2   business_status  245 non-null    object
#  3   types            245 non-null    object
#  4   lat              245 non-null    float64
#  5   lng              245 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 11.6+ KB

# %%
cols_to_drop = ['place_id', 'lat', 'lng', 'business_status']

# %%
with open('vectorizers/dummy_columns_list_NN.txt', 'r') as file:
    all_dummies = file.read().splitlines()

# %%
df_preprocessed = preprocess_data(df, cols_to_drop, vectorizer_path='vectorizers/tfidf_vectorizer_NN.joblib', all_dummies=all_dummies)

# %%
df_preprocessed
# Out:
# <245x1085 sparse matrix of type '<class 'numpy.float64'>'
# 	with 622 stored elements in COOrdinate format>

# %%
print(df_preprocessed.shape)
# Out:
# (245, 1085)
